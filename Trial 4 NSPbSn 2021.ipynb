# %% [markdown]
# # TRIAL 4: Analysis of Nickel Strike and PbSn Plated HTS Tape Data (Current vs Voltage) Before and After Solder Degradation
# Data taken at 77K rig at 148 Sidney Street. In this notebook, each sample has three cells.
#
# The first cell is the calculation of high temperature superconducting performance degradation, the second an interactive plot of the performance of the tape before winding, the third an interactive plot of the performance of the tape after a winding.
#
# Note: Some of the plots have different sample names than the sample section name they are in. <br> Data collection and notebook by Denisse Cordova Carrizales (dcordovacarrizales@cfs.energy).

# %%
import mpld3

# %%
mpld3.enable_notebook()

# %% [markdown]
# ## 20 Minutes Solder: SOX 853-L (2)
# Pre-tests 20210301 77-81
#
# Post-tests 20210517 27-29
#
# Note: These tapes had already been used before for different testing.

# %%
initial_IC = [108.470317, 108.888065, 109.046061 ]#shot3,4,5
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [51.2741045, 51.7816144] #shot39,40. a third was not available
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  108.80148100000001
# Avg. Post IC  51.52785945
# Avg. Degradation  0.5264047972839635

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201013
# manual(m) or list(l)
#  l
# start shot
#  3
# stop shot
#  5
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  108.470317 +/- 0.15252326 (0.14%) (init = 125)
#     n:   61.6057881 +/- 3.73525174 (6.06%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.940
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  108.888065 +/- 0.07568119 (0.07%) (init = 125)
#     n:   58.0493812 +/- 2.28005446 (3.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.877
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  109.046061 +/- 0.05547419 (0.05%) (init = 125)
#     n:   52.5240922 +/- 1.35227069 (2.57%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201022
# manual(m) or list(l)
#  l
# start shot
#  39
# stop shot
#  40
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  51.2741045 +/- 0.08199579 (0.16%) (init = 125)
#     n:   35.6450282 +/- 1.95023572 (5.47%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.887
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  51.7816144 +/- 0.03629518 (0.07%) (init = 125)
#     n:   27.1452333 +/- 1.04639159 (3.85%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.107
# ##################plotting!!!############

# %% [markdown]
# ## 20 Minutes Solder: DCC_Ni_006
# Pre-test 20210415 48-52
#
# Post-test 20210519 10-12

# %%
initial_IC = [117.922464, 118.450162]#shot7,8
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [49.1290450, 48.9892117, 49.2333604 ] #shot39,40. a third was not available
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  118.18631300000001
# Avg. Post IC  49.1172057
# Avg. Degradation  0.5844086810627556

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201013
# manual(m) or list(l)
#  l
# start shot
#  7
# stop shot
#  8
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  117.922464 +/- 0.03730557 (0.03%) (init = 125)
#     n:   41.9252504 +/- 0.75391634 (1.80%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.745
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  118.450162 +/- 0.04176202 (0.04%) (init = 125)
#     n:   40.2078885 +/- 0.73705270 (1.83%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.772
# ##################plotting!!!############

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201030
# manual(m) or list(l)
#  l
# start shot
#  82
# stop shot
#  84
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  49.1290450 +/- 0.33267514 (0.68%) (init = 125)
#     n:   14.2693089 +/- 0.63298277 (4.44%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.975
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  48.9892117 +/- 0.36157869 (0.74%) (init = 125)
#     n:   13.6830406 +/- 0.61003281 (4.46%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.977
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  49.2333604 +/- 0.36161764 (0.73%) (init = 125)
#     n:   13.9425353 +/- 0.61136776 (4.38%) (init = 20)
# ...

# %% [markdown]
# ## 15 Minutes Solder: RJ_007
# Pre-Test 20210315 43-47
#
# Post-Test 20210519 13-15

# %%
initial_IC = [157.414592, 157.607234, 157.651808]#shot9,10,11
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [ 155.525592, 155.693977 ,156.319946 ] #shot45,46,47
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  157.557878
# Avg. Post IC  155.84650499999998
# Avg. Degradation  0.010861868804808439

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201013
# manual(m) or list(l)
#  l
# start shot
#  9
# stop shot
#  11
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  157.414592 +/- 0.13547445 (0.09%) (init = 125)
#     n:   40.3236764 +/- 1.08101240 (2.68%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.925
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  157.607234 +/- 0.02703164 (0.02%) (init = 125)
#     n:   36.6481199 +/- 0.40611914 (1.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.495
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  157.651808 +/- 0.02832384 (0.02%) (init = 125)
#     n:   35.3201148 +/- 0.39031589 (1.11%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201022
# manual(m) or list(l)
#  l
# start shot
#  45
# stop shot
#  47
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  155.525592 +/- 0.07125881 (0.05%) (init = 125)
#     n:   39.8129122 +/- 0.74708964 (1.88%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.860
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  155.693977 +/- 0.07101458 (0.05%) (init = 125)
#     n:   37.4558586 +/- 0.67846284 (1.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.851
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  156.319946 +/- 0.01859542 (0.01%) (init = 125)
#     n:   30.4676182 +/- 0.21844660 (0.72%) (init = 20)
# ...

# %% [markdown]
# ## 15 Minutes Solder: DCC_Ni_002
# Pre-Test: 20210415 20-24
#
# Post-Test: 20210518 18-20

# %% [markdown]
# ### Analysis for Granola

# %%
initial_IC = [72.1200237,  71.2749456, 70.9764396  ]#shot12,13,14
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [86.9885240] #shot
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  71.4571363
# Avg. Post IC  86.988524
# Avg. Degradation  -0.21735250675025997

# %% [markdown]
# ### Analsyis for Egg

# %% [markdown]
# The below raw data is data for pre and post tests for Granola. The pre-test is also a post-test for Egg. Jessica Cheng took pre-test data (located in Solder Data All). 117.3 A was initial IC for Egg pre-test.

# %%
avg_initial_IC =
print("Avg. Initial IC " , avg_initial_IC)

avg_post_IC = 71.4571363
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
#   File "<ipython-input-55-f2fc1a4d3748>", line 1
#     avg_initial_IC =
#                     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Pre-Tests Granola (and Post-Tests for Egg)

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201013
# manual(m) or list(l)
#  l
# start shot
#  12
# stop shot
#  14
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  72.1200237 +/- 0.40571307 (0.56%) (init = 125)
#     n:   8.47117084 +/- 0.46181883 (5.45%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.842
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  71.2749456 +/- 0.44488270 (0.62%) (init = 125)
#     n:   9.54066501 +/- 0.49203073 (5.16%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.911
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  70.9764396 +/- 0.50506304 (0.71%) (init = 125)
#     n:   7.55483531 +/- 0.42253769 (5.59%) (init = 20)
# ...

# %% [markdown]
# ### Post-Tests Granola

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201103
# manual(m) or list(l)
#  m
# Input shot numbers (separated by spaces):
#  24
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  86.9885240 +/- 1.15971412 (1.33%) (init = 125)
#     n:   13.9172955 +/- 1.25896183 (9.05%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.972
# ##################plotting!!!############

# %% [markdown]
# ## 10 Minutes Solder: 7-PP
# Pre-Test: 20210414 52-56
#
# Post-Test: 20210519 16-18

# %% [markdown]
# ## Sample: 7
# TFMC Notes: pre-test on new tape

# %%
initial_IC = [170.117466]#shot16. more were not available
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [168.593711, 168.362330, 168.428065 ] #shot39,40. a third was not available
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  170.117466
# Avg. Post IC  168.4613686666667
# Avg. Degradation  0.009735022348224542

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201013
# manual(m) or list(l)
#  l
# start shot
#  16
# stop shot
#  16
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  170.117466 +/- 0.06185721 (0.04%) (init = 125)
#     n:   42.7810668 +/- 0.68466248 (1.60%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.863
# ##################plotting!!!############

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201103
# manual(m) or list(l)
#  l
# start shot
#  60
# stop shot
#  62
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  168.593711 +/- 0.02253441 (0.01%) (init = 125)
#     n:   33.6129107 +/- 0.29800742 (0.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.257
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  168.362330 +/- 0.02319408 (0.01%) (init = 125)
#     n:   33.3734008 +/- 0.29696026 (0.89%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.315
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  168.428065 +/- 0.01871222 (0.01%) (init = 125)
#     n:   31.8106800 +/- 0.21958939 (0.69%) (init = 20)
# ...

# %% [markdown]
# ## 10 Minutes Solder: DCC_Ni_003
# Pre-Test: 20210415 26-30
#
# Post-Test: 20210519 37-39

# %%
initial_IC = [161.602020, 162.713080 ]#shot191, 192
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [ 100.131683, 99.7091289, 100.570818 ] #shot4,5,6
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  162.15755000000001
# Avg. Post IC  100.13720996666666
# Avg. Degradation  0.38246964161294583

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201002
# manual(m) or list(l)
#  l
# start shot
#  191
# stop shot
#  192
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  161.602020 +/- 0.11471309 (0.07%) (init = 125)
#     n:   39.9957280 +/- 1.10303940 (2.76%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.878
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  162.713080 +/- 0.03216215 (0.02%) (init = 125)
#     n:   28.2216021 +/- 0.17398006 (0.62%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.840
# ##################plotting!!!############

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201102
# manual(m) or list(l)
#  l
# start shot
#  4
# stop shot
#  6
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  100.131683 +/- 0.06304313 (0.06%) (init = 125)
#     n:   35.0572714 +/- 0.93502080 (2.67%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.799
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  99.7091289 +/- 0.01723504 (0.02%) (init = 125)
#     n:   84.4299354 +/- 2.11668057 (2.51%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.486
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  100.570818 +/- 0.01755675 (0.02%) (init = 125)
#     n:   59.0520328 +/- 1.22460847 (2.07%) (init = 20)
# ##################plotting!!!############

# %% [markdown]
# ## 5 Minutes Solder: 3-PP
# Pre-Test: 20210406 78-114
#
# Post-Test: 20210519 67-70

# %%
initial_IC = [153.047946, 154.715937, 154.856857 ]#shot197,198,199
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [105.683784, 105.304636 ] #shot7,8. a third was not available
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  154.20691333333332
# Avg. Post IC  105.49421000000001
# Avg. Degradation  0.3158918253427201

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201002
# manual(m) or list(l)
#  l
# start shot
#  197
# stop shot
#  199
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  153.047946 +/- 0.23429919 (0.15%) (init = 125)
#     n:   40.3707940 +/- 1.76706821 (4.38%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.936
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  154.715937 +/- 0.02748240 (0.02%) (init = 125)
#     n:   26.2152011 +/- 0.19690653 (0.75%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.613
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  154.856857 +/- 0.03721193 (0.02%) (init = 125)
#     n:   25.6135940 +/- 0.15663839 (0.61%) (init = 20)
# ...

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201102
# manual(m) or list(l)
#  l
# start shot
#  7
# stop shot
#  8
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  105.683784 +/- 0.06704948 (0.06%) (init = 125)
#     n:   22.0492609 +/- 0.39037454 (1.77%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.762
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  105.304636 +/- 0.01862002 (0.02%) (init = 125)
#     n:   29.7101411 +/- 0.27528118 (0.93%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.490
# ##################plotting!!!############

# %% [markdown]
# ## 5 Minutes Solder: DCC_Ni_001
# Pre-Test: 20210415 14-18
#
# Post-Test: 20210519 40-43

# %%
initial_IC = [101.683913, 101.826354, 101.856986 ]#shot
avg_initial_IC = (sum(initial_IC))/len(initial_IC)
print("Avg. Initial IC " , avg_initial_IC)

post_IC = [47.3105297, 47.4578514 ] #shot86,87. a third was not available
avg_post_IC = (sum(post_IC))/len(post_IC)
print("Avg. Post IC " , avg_post_IC)

avg_degradation = 1 - avg_post_IC/avg_initial_IC
print("Avg. Degradation " , avg_degradation)
# Out:
# Avg. Initial IC  101.78908433333334
# Avg. Post IC  47.38419055
# Avg. Degradation  0.5344865231832832

# %% [markdown]
# ### Pre-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201013
# manual(m) or list(l)
#  l
# start shot
#  0
# stop shot
#  2
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  101.683913 +/- 0.07919966 (0.08%) (init = 125)
#     n:   40.2373719 +/- 1.43004075 (3.55%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.831
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  101.826354 +/- 0.09201835 (0.09%) (init = 125)
#     n:   36.5672814 +/- 1.32493334 (3.62%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) = -0.845
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 092520-10222020
# [[Variables]]
#     Ic:  101.856986 +/- 0.10473505 (0.10%) (init = 125)
#     n:   35.9016098 +/- 1.36796931 (3.81%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
# ...

# %% [markdown]
# ### Post-Tests

# %%
# %run calculate_IC.py
# Out:
# Input date in YYYYMMDD format
#  20201030
# manual(m) or list(l)
#  l
# start shot
#  86
# stop shot
#  87
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  47.3105297 +/- 0.10689764 (0.23%) (init = 125)
#     n:   17.7942420 +/- 0.78601478 (4.42%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.845
# ##################plotting!!!############
# Name of Data Folder TFMC
# Date of Data Batch 10302020-11032020
# [[Variables]]
#     Ic:  47.4578514 +/- 0.12623344 (0.27%) (init = 125)
#     n:   17.8636468 +/- 0.77479162 (4.34%) (init = 20)
# [[Correlations]] (unreported correlations are < 0.100)
#     C(Ic, n) =  0.896
# ##################plotting!!!############
